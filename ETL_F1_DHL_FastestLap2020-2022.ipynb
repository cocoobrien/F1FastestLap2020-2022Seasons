# %% [markdown]
# ## F1 DHL Fastest Lap 2020-2022
# https://www.formula1.com/en/results.html/2022/fastest-laps.html

# %%
# Import necessary libraries
from bs4 import BeautifulSoup
from csv import writer
import pandas as pd
import requests
from datetime import datetime

# %%
# Reading Webpage, Parse with Beautiful Soup
F1_2022_webpage = requests.get("https://www.formula1.com/en/results.html/2022/fastest-laps.html")
# Initialize a BeautifulSoup object to read and parse the webpage read
# This is like calling the __init__ function in BeautifulSoup
bs_2022 = BeautifulSoup(F1_2022_webpage.content, "html.parser")

F1_2021_webpage = requests.get("https://www.formula1.com/en/results.html/2021/fastest-laps.html")
bs_2021 = BeautifulSoup(F1_2021_webpage.content, "html.parser")

F1_2020_webpage = requests.get("https://www.formula1.com/en/results.html/2020/fastest-laps.html")
bs_2020 = BeautifulSoup(F1_2020_webpage.content, "html.parser")

# %%
table_2022 = bs_2022.find("table")

table_2021 = bs_2021.find("table")

table_2020 = bs_2020.find("table")

# %%
# Finding all the necessary rows from pages
rows_2022 = table_2022.find_all("tr") 
rows_2021 = table_2021.find_all("tr")
rows_2020 = table_2020.find_all("tr")

# %%
final_data = []

for row in rows_2022[1:]:
    cells = row.find_all(["td", "th"])
    cells_text = [cell.get_text(strip = True) for cell in cells]
    for cell in cells_text:  # Adding year to the data
        cells_text.insert(1,int(2022)) 
        final_data.append(cells_text)
        break # this prints list w/ nested lists as values

for row in rows_2021[1:]:
    cells = row.find_all(["td", "th"])
    cells_text = [cell.get_text(strip = True) for cell in cells]

    for cell in cells_text:  # Adding year to the data
        cells_text.insert(1,int(2021)) 
        final_data.append(cells_text)
        break # this prints list w/ nested lists as values
        
for row in rows_2020[1:]:
    cells = row.find_all(["td", "th"])
    cells_text = [cell.get_text(strip = True) for cell in cells]
    # print(cells_text) - uncomment to see below
    # results in ['', 'Bahrain', 'CharlesLeclercLEC', 'Ferrari', '1:34.570', ''] 
    #            ['', 'Saudi Arabia', 'CharlesLeclercLEC', 'Ferrari', '1:31.634', '']
    #            ['', 'Australia', 'CharlesLeclercLEC', 'Ferrari', '1:20.260', '']
    #            etc... 
    for cell in cells_text:  # Adding year to the data
        cells_text.insert(1,int(2020)) 
        final_data.append(cells_text)
        break # this prints list w/ nested lists as values

print(final_data)
# Out:
# [['', 2022, 'Bahrain', 'CharlesLeclercLEC', 'Ferrari', '1:34.570', ''], ['', 2022, 'Saudi Arabia', 'CharlesLeclercLEC', 'Ferrari', '1:31.634', ''], ['', 2022, 'Australia', 'CharlesLeclercLEC', 'Ferrari', '1:20.260', ''], ['', 2022, 'Emilia Romagna', 'MaxVerstappenVER', 'Red Bull Racing RBPT', '1:18.446', ''], ['', 2022, 'Miami', 'MaxVerstappenVER', 'Red Bull Racing RBPT', '1:31.361', ''], ['', 2022, 'Spain', 'SergioPerezPER', 'Red Bull Racing RBPT', '1:24.108', ''], ['', 2022, 'Monaco', 'LandoNorrisNOR', 'McLaren Mercedes', '1:14.693', ''], ['', 2022, 'Azerbaijan', 'SergioPerezPER', 'Red Bull Racing RBPT', '1:46.046', ''], ['', 2022, 'Canada', 'CarlosSainzSAI', 'Ferrari', '1:15.749', ''], ['', 2022, 'Great Britain', 'LewisHamiltonHAM', 'Mercedes', '1:30.510', ''], ['', 2022, 'Austria', 'MaxVerstappenVER', 'Red Bull Racing RBPT', '1:07.275', ''], ['', 2022, 'France', 'CarlosSainzSAI', 'Ferrari', '1:35.781', ''], ['', 2022, 'Hungary', 'LewisHamiltonHAM', 'Mercedes', '1:21.386', ''], ['', 2022, 'Belgium', 'MaxVerstappenVER', 'Red Bull Racing RBPT', '1:49.354', ''], ['', 2022, 'Netherlands', 'MaxVerstappenVER', 'Red Bull Racing RBPT', '1:13.652', ''], ['', 2022, 'Italy', 'SergioPerezPER', 'Red Bull Racing RBPT', '1:24.030', ''], ['', 2022, 'Singapore', 'GeorgeRussellRUS', 'Mercedes', '1:46.458', ''], ['', 2022, 'Japan', 'ZhouGuanyuZHO', 'Alfa Romeo Ferrari', '1:44.411', ''], ['', 2022, 'United States', 'GeorgeRussellRUS', 'Mercedes', '1:38.788', ''], ['', 2022, 'Mexico', 'GeorgeRussellRUS', 'Mercedes', '1:20.153', ''], ['', 2022, 'Brazil', 'GeorgeRussellRUS', 'Mercedes', '1:13.785', ''], ['', 2022, 'Abu Dhabi', 'LandoNorrisNOR', 'McLaren Mercedes', '1:28.391', ''], ['', 2021, 'Bahrain', 'ValtteriBottasBOT', 'Mercedes', '1:32.090', ''], ['', 2021, 'Emilia Romagna', 'LewisHamiltonHAM', 'Mercedes', '1:16.702', ''], ['', 2021, 'Portugal', 'ValtteriBottasBOT', 'Mercedes', '1:19.865', ''], ['', 2021, 'Spain', 'MaxVerstappenVER', 'Red Bull Racing Honda', '1:18.149', ''], ['', 2021, 'Monaco', 'LewisHamiltonHAM', 'Mercedes', '1:12.909', ''], ['', 2021, 'Azerbaijan', 'MaxVerstappenVER', 'Red Bull Racing Honda', '1:44.481', ''], ['', 2021, 'France', 'MaxVerstappenVER', 'Red Bull Racing Honda', '1:36.404', ''], ['', 2021, 'Styria', 'LewisHamiltonHAM', 'Mercedes', '1:07.058', ''], ['', 2021, 'Austria', 'MaxVerstappenVER', 'Red Bull Racing Honda', '1:06.200', ''], ['', 2021, 'Great Britain', 'SergioPerezPER', 'Red Bull Racing Honda', '1:28.617', ''], ['', 2021, 'Hungary', 'PierreGaslyGAS', 'AlphaTauri Honda', '1:18.394', ''], ['', 2021, 'Netherlands', 'LewisHamiltonHAM', 'Mercedes', '1:11.097', ''], ['', 2021, 'Italy', 'DanielRicciardoRIC', 'McLaren Mercedes', '1:24.812', ''], ['', 2021, 'Russia', 'LandoNorrisNOR', 'McLaren Mercedes', '1:37.423', ''], ['', 2021, 'Turkey', 'ValtteriBottasBOT', 'Mercedes', '1:30.432', ''], ['', 2021, 'United States', 'LewisHamiltonHAM', 'Mercedes', '1:38.485', ''], ['', 2021, 'Mexico', 'ValtteriBottasBOT', 'Mercedes', '1:17.774', ''], ['', 2021, 'Brazil', 'SergioPerezPER', 'Red Bull Racing Honda', '1:11.010', ''], ['', 2021, 'Qatar', 'MaxVerstappenVER', 'Red Bull Racing Honda', '1:23.196', ''], ['', 2021, 'Saudi Arabia', 'LewisHamiltonHAM', 'Mercedes', '1:30.734', ''], ['', 2021, 'Abu Dhabi', 'MaxVerstappenVER', 'Red Bull Racing Honda', '1:26.103', ''], ['', 2020, 'Austria', 'LandoNorrisNOR', 'McLaren Renault', '1:07.475', ''], ['', 2020, 'Styria', 'CarlosSainzSAI', 'McLaren Renault', '1:05.619', ''], ['', 2020, 'Hungary', 'LewisHamiltonHAM', 'Mercedes', '1:16.627', ''], ['', 2020, 'Great Britain', 'MaxVerstappenVER', 'Red Bull Racing Honda', '1:27.097', ''], ['', 2020, '70th Anniversary', 'LewisHamiltonHAM', 'Mercedes', '1:28.451', ''], ['', 2020, 'Spain', 'ValtteriBottasBOT', 'Mercedes', '1:18.183', ''], ['', 2020, 'Belgium', 'DanielRicciardoRIC', 'Renault', '1:47.483', ''], ['', 2020, 'Italy', 'LewisHamiltonHAM', 'Mercedes', '1:22.746', ''], ['', 2020, 'Tuscany', 'LewisHamiltonHAM', 'Mercedes', '1:18.833', ''] ...

# %%
df = pd.DataFrame(final_data, columns =['','Year', 'Grand Prix', 'Driver', 'Car', 'Lap Time', ''])
del df[""]
df
# Out:
#     Year        Grand Prix              Driver                    Car  \
# 0   2022           Bahrain   CharlesLeclercLEC                Ferrari
# 1   2022      Saudi Arabia   CharlesLeclercLEC                Ferrari
# 2   2022         Australia   CharlesLeclercLEC                Ferrari
# 3   2022    Emilia Romagna    MaxVerstappenVER   Red Bull Racing RBPT
# 4   2022             Miami    MaxVerstappenVER   Red Bull Racing RBPT
# 5   2022             Spain      SergioPerezPER   Red Bull Racing RBPT
# 6   2022            Monaco      LandoNorrisNOR       McLaren Mercedes
# 7   2022        Azerbaijan      SergioPerezPER   Red Bull Racing RBPT
# 8   2022            Canada      CarlosSainzSAI                Ferrari
# 9   2022     Great Britain    LewisHamiltonHAM               Mercedes
# 10  2022           Austria    MaxVerstappenVER   Red Bull Racing RBPT
# 11  2022            France      CarlosSainzSAI                Ferrari
# 12  2022           Hungary    LewisHamiltonHAM               Mercedes
# 13  2022           Belgium    MaxVerstappenVER   Red Bull Racing RBPT
# 14  2022       Netherlands    MaxVerstappenVER   Red Bull Racing RBPT
# 15  2022             Italy      SergioPerezPER   Red Bull Racing RBPT
# 16  2022         Singapore    GeorgeRussellRUS               Mercedes
# 17  2022             Japan       ZhouGuanyuZHO     Alfa Romeo Ferrari
# 18  2022     United States    GeorgeRussellRUS               Mercedes
# 19  2022            Mexico    GeorgeRussellRUS               Mercedes
# 20  2022            Brazil    GeorgeRussellRUS               Mercedes
# 21  2022         Abu Dhabi      LandoNorrisNOR       McLaren Mercedes
# 22  2021           Bahrain   ValtteriBottasBOT               Mercedes
# 23  2021    Emilia Romagna    LewisHamiltonHAM               Mercedes
# 24  2021          Portugal   ValtteriBottasBOT               Mercedes
# 25  2021             Spain    MaxVerstappenVER  Red Bull Racing Honda
# 26  2021            Monaco    LewisHamiltonHAM               Mercedes
# 27  2021        Azerbaijan    MaxVerstappenVER  Red Bull Racing Honda
# 28  2021            France    MaxVerstappenVER  Red Bull Racing Honda
# 29  2021            Styria    LewisHamiltonHAM               Mercedes
# 30  2021           Austria    MaxVerstappenVER  Red Bull Racing Honda
# 31  2021     Great Britain      SergioPerezPER  Red Bull Racing Honda
# 32  2021           Hungary      PierreGaslyGAS       AlphaTauri Honda
# 33  2021       Netherlands    LewisHamiltonHAM               Mercedes
# 34  2021             Italy  DanielRicciardoRIC       McLaren Mercedes
# 35  2021            Russia      LandoNorrisNOR       McLaren Mercedes
# 36  2021            Turkey   ValtteriBottasBOT               Mercedes
# 37  2021     United States    LewisHamiltonHAM               Mercedes
# 38  2021            Mexico   ValtteriBottasBOT               Mercedes
# 39  2021            Brazil      SergioPerezPER  Red Bull Racing Honda
# 40  2021             Qatar    MaxVerstappenVER  Red Bull Racing Honda
# 41  2021      Saudi Arabia    LewisHamiltonHAM               Mercedes
# 42  2021         Abu Dhabi    MaxVerstappenVER  Red Bull Racing Honda
# 43  2020           Austria      LandoNorrisNOR        McLaren Renault
# 44  2020            Styria      CarlosSainzSAI        McLaren Renault
# 45  2020           Hungary    LewisHamiltonHAM               Mercedes
# 46  2020     Great Britain    MaxVerstappenVER  Red Bull Racing Honda
# 47  2020  70th Anniversary    LewisHamiltonHAM               Mercedes
# 48  2020             Spain   ValtteriBottasBOT               Mercedes
# 49  2020           Belgium  DanielRicciardoRIC                Renault
# 50  2020             Italy    LewisHamiltonHAM               Mercedes
# 51  2020           Tuscany    LewisHamiltonHAM               Mercedes
# 52  2020            Russia   ValtteriBottasBOT               Mercedes
# 53  2020             Eifel    MaxVerstappenVER  Red Bull Racing Honda
# 54  2020          Portugal    LewisHamiltonHAM               Mercedes
# 55  2020    Emilia Romagna    LewisHamiltonHAM               Mercedes
# 56  2020            Turkey      LandoNorrisNOR        McLaren Renault
# 57  2020           Bahrain    MaxVerstappenVER  Red Bull Racing Honda
# 58  2020            Sakhir    GeorgeRussellRUS               Mercedes
# 59  2020         Abu Dhabi  DanielRicciardoRIC                Renault
#
#     Lap Time
# 0   1:34.570
# 1   1:31.634
# 2   1:20.260
# 3   1:18.446
# 4   1:31.361
# 5   1:24.108
# 6   1:14.693
# 7   1:46.046
# 8   1:15.749
# 9   1:30.510
# 10  1:07.275
# 11  1:35.781
# 12  1:21.386
# 13  1:49.354
# 14  1:13.652
# 15  1:24.030
# 16  1:46.458
# 17  1:44.411
# 18  1:38.788
# 19  1:20.153
# 20  1:13.785
# 21  1:28.391
# 22  1:32.090
# 23  1:16.702
# 24  1:19.865
# 25  1:18.149
# 26  1:12.909
# 27  1:44.481
# 28  1:36.404
# 29  1:07.058
# 30  1:06.200
# 31  1:28.617
# 32  1:18.394
# 33  1:11.097
# 34  1:24.812
# 35  1:37.423
# 36  1:30.432
# 37  1:38.485
# 38  1:17.774
# 39  1:11.010
# 40  1:23.196
# 41  1:30.734
# 42  1:26.103
# 43  1:07.475
# 44  1:05.619
# 45  1:16.627
# 46  1:27.097
# 47  1:28.451
# 48  1:18.183
# 49  1:47.483
# 50  1:22.746
# 51  1:18.833
# 52  1:37.030
# 53  1:28.139
# 54  1:18.750
# 55  1:15.484
# 56  1:36.806
# 57  1:32.014
# 58    55.404
# 59  1:40.926

# %%
def normalize_laptime (x):
    if ":" not in x:
        return '0:' + x
    else:
        return '0' + x

# %%
# Calling normalize laptime function data
df['Lap Time'] = df['Lap Time'].apply(normalize_laptime)

# %%
# Red Bull changed name from "Red Bull Honda" (2020-2021) to "Red Bull RBPT" (2022); changing all occurences to updated name
def normalize_carname (x):
    if "Red Bull Racing Honda" in x:
        RB_name = x.replace("Red Bull Racing Honda", "Red Bull Racing RBPT")
        return RB_name
    elif "McLaren Mercedes" in x: 
        ML = x.replace("McLaren Mercedes", "McLaren")
        return ML
    elif "McLaren Renault" in x: 
        ML_2 = x.replace("McLaren Renault", "McLaren")
        return ML_2
    elif "Alfa Romeo Ferrari" in x: 
        AR = x.replace("Alfa Romeo Ferrari", "Alfa Romeo") 
        return AR
    elif "AlphaTauri Honda" in x: 
        AT = x.replace("AlphaTauri Honda", "AlphaTauri")
        return AT
    else: 
        return x

# %%
# Calling normalize car function
df['Car'] = df['Car'].apply(normalize_carname)

# %%
df
# Out:
#     Year        Grand Prix              Driver                   Car  \
# 0   2022           Bahrain   CharlesLeclercLEC               Ferrari
# 1   2022      Saudi Arabia   CharlesLeclercLEC               Ferrari
# 2   2022         Australia   CharlesLeclercLEC               Ferrari
# 3   2022    Emilia Romagna    MaxVerstappenVER  Red Bull Racing RBPT
# 4   2022             Miami    MaxVerstappenVER  Red Bull Racing RBPT
# 5   2022             Spain      SergioPerezPER  Red Bull Racing RBPT
# 6   2022            Monaco      LandoNorrisNOR               McLaren
# 7   2022        Azerbaijan      SergioPerezPER  Red Bull Racing RBPT
# 8   2022            Canada      CarlosSainzSAI               Ferrari
# 9   2022     Great Britain    LewisHamiltonHAM              Mercedes
# 10  2022           Austria    MaxVerstappenVER  Red Bull Racing RBPT
# 11  2022            France      CarlosSainzSAI               Ferrari
# 12  2022           Hungary    LewisHamiltonHAM              Mercedes
# 13  2022           Belgium    MaxVerstappenVER  Red Bull Racing RBPT
# 14  2022       Netherlands    MaxVerstappenVER  Red Bull Racing RBPT
# 15  2022             Italy      SergioPerezPER  Red Bull Racing RBPT
# 16  2022         Singapore    GeorgeRussellRUS              Mercedes
# 17  2022             Japan       ZhouGuanyuZHO            Alfa Romeo
# 18  2022     United States    GeorgeRussellRUS              Mercedes
# 19  2022            Mexico    GeorgeRussellRUS              Mercedes
# 20  2022            Brazil    GeorgeRussellRUS              Mercedes
# 21  2022         Abu Dhabi      LandoNorrisNOR               McLaren
# 22  2021           Bahrain   ValtteriBottasBOT              Mercedes
# 23  2021    Emilia Romagna    LewisHamiltonHAM              Mercedes
# 24  2021          Portugal   ValtteriBottasBOT              Mercedes
# 25  2021             Spain    MaxVerstappenVER  Red Bull Racing RBPT
# 26  2021            Monaco    LewisHamiltonHAM              Mercedes
# 27  2021        Azerbaijan    MaxVerstappenVER  Red Bull Racing RBPT
# 28  2021            France    MaxVerstappenVER  Red Bull Racing RBPT
# 29  2021            Styria    LewisHamiltonHAM              Mercedes
# 30  2021           Austria    MaxVerstappenVER  Red Bull Racing RBPT
# 31  2021     Great Britain      SergioPerezPER  Red Bull Racing RBPT
# 32  2021           Hungary      PierreGaslyGAS            AlphaTauri
# 33  2021       Netherlands    LewisHamiltonHAM              Mercedes
# 34  2021             Italy  DanielRicciardoRIC               McLaren
# 35  2021            Russia      LandoNorrisNOR               McLaren
# 36  2021            Turkey   ValtteriBottasBOT              Mercedes
# 37  2021     United States    LewisHamiltonHAM              Mercedes
# 38  2021            Mexico   ValtteriBottasBOT              Mercedes
# 39  2021            Brazil      SergioPerezPER  Red Bull Racing RBPT
# 40  2021             Qatar    MaxVerstappenVER  Red Bull Racing RBPT
# 41  2021      Saudi Arabia    LewisHamiltonHAM              Mercedes
# 42  2021         Abu Dhabi    MaxVerstappenVER  Red Bull Racing RBPT
# 43  2020           Austria      LandoNorrisNOR               McLaren
# 44  2020            Styria      CarlosSainzSAI               McLaren
# 45  2020           Hungary    LewisHamiltonHAM              Mercedes
# 46  2020     Great Britain    MaxVerstappenVER  Red Bull Racing RBPT
# 47  2020  70th Anniversary    LewisHamiltonHAM              Mercedes
# 48  2020             Spain   ValtteriBottasBOT              Mercedes
# 49  2020           Belgium  DanielRicciardoRIC               Renault
# 50  2020             Italy    LewisHamiltonHAM              Mercedes
# 51  2020           Tuscany    LewisHamiltonHAM              Mercedes
# 52  2020            Russia   ValtteriBottasBOT              Mercedes
# 53  2020             Eifel    MaxVerstappenVER  Red Bull Racing RBPT
# 54  2020          Portugal    LewisHamiltonHAM              Mercedes
# 55  2020    Emilia Romagna    LewisHamiltonHAM              Mercedes
# 56  2020            Turkey      LandoNorrisNOR               McLaren
# 57  2020           Bahrain    MaxVerstappenVER  Red Bull Racing RBPT
# 58  2020            Sakhir    GeorgeRussellRUS              Mercedes
# 59  2020         Abu Dhabi  DanielRicciardoRIC               Renault
#
#      Lap Time
# 0   01:34.570
# 1   01:31.634
# 2   01:20.260
# 3   01:18.446
# 4   01:31.361
# 5   01:24.108
# 6   01:14.693
# 7   01:46.046
# 8   01:15.749
# 9   01:30.510
# 10  01:07.275
# 11  01:35.781
# 12  01:21.386
# 13  01:49.354
# 14  01:13.652
# 15  01:24.030
# 16  01:46.458
# 17  01:44.411
# 18  01:38.788
# 19  01:20.153
# 20  01:13.785
# 21  01:28.391
# 22  01:32.090
# 23  01:16.702
# 24  01:19.865
# 25  01:18.149
# 26  01:12.909
# 27  01:44.481
# 28  01:36.404
# 29  01:07.058
# 30  01:06.200
# 31  01:28.617
# 32  01:18.394
# 33  01:11.097
# 34  01:24.812
# 35  01:37.423
# 36  01:30.432
# 37  01:38.485
# 38  01:17.774
# 39  01:11.010
# 40  01:23.196
# 41  01:30.734
# 42  01:26.103
# 43  01:07.475
# 44  01:05.619
# 45  01:16.627
# 46  01:27.097
# 47  01:28.451
# 48  01:18.183
# 49  01:47.483
# 50  01:22.746
# 51  01:18.833
# 52  01:37.030
# 53  01:28.139
# 54  01:18.750
# 55  01:15.484
# 56  01:36.806
# 57  01:32.014
# 58   0:55.404
# 59  01:40.926

# %%
df['Lap Time'] = pd.to_datetime(df['Lap Time']).dt.strftime('%H:%M')

# %%
# Coverting Lap Time to dtype: float64
def convert(x):
    x = x.split(":")
    x = x[0]+"."+x[1]
    x = float(x)
    return x

df['Lap Time'] = df['Lap Time'].apply(convert)
df
# Out:
#     Year        Grand Prix              Driver                   Car  Lap Time
# 0   2022           Bahrain   CharlesLeclercLEC               Ferrari      1.34
# 1   2022      Saudi Arabia   CharlesLeclercLEC               Ferrari      1.31
# 2   2022         Australia   CharlesLeclercLEC               Ferrari      1.20
# 3   2022    Emilia Romagna    MaxVerstappenVER  Red Bull Racing RBPT      1.18
# 4   2022             Miami    MaxVerstappenVER  Red Bull Racing RBPT      1.31
# 5   2022             Spain      SergioPerezPER  Red Bull Racing RBPT      1.24
# 6   2022            Monaco      LandoNorrisNOR               McLaren      1.14
# 7   2022        Azerbaijan      SergioPerezPER  Red Bull Racing RBPT      1.46
# 8   2022            Canada      CarlosSainzSAI               Ferrari      1.15
# 9   2022     Great Britain    LewisHamiltonHAM              Mercedes      1.30
# 10  2022           Austria    MaxVerstappenVER  Red Bull Racing RBPT      1.07
# 11  2022            France      CarlosSainzSAI               Ferrari      1.35
# 12  2022           Hungary    LewisHamiltonHAM              Mercedes      1.21
# 13  2022           Belgium    MaxVerstappenVER  Red Bull Racing RBPT      1.49
# 14  2022       Netherlands    MaxVerstappenVER  Red Bull Racing RBPT      1.13
# 15  2022             Italy      SergioPerezPER  Red Bull Racing RBPT      1.24
# 16  2022         Singapore    GeorgeRussellRUS              Mercedes      1.46
# 17  2022             Japan       ZhouGuanyuZHO            Alfa Romeo      1.44
# 18  2022     United States    GeorgeRussellRUS              Mercedes      1.38
# 19  2022            Mexico    GeorgeRussellRUS              Mercedes      1.20
# 20  2022            Brazil    GeorgeRussellRUS              Mercedes      1.13
# 21  2022         Abu Dhabi      LandoNorrisNOR               McLaren      1.28
# 22  2021           Bahrain   ValtteriBottasBOT              Mercedes      1.32
# 23  2021    Emilia Romagna    LewisHamiltonHAM              Mercedes      1.16
# 24  2021          Portugal   ValtteriBottasBOT              Mercedes      1.19
# 25  2021             Spain    MaxVerstappenVER  Red Bull Racing RBPT      1.18
# 26  2021            Monaco    LewisHamiltonHAM              Mercedes      1.12
# 27  2021        Azerbaijan    MaxVerstappenVER  Red Bull Racing RBPT      1.44
# 28  2021            France    MaxVerstappenVER  Red Bull Racing RBPT      1.36
# 29  2021            Styria    LewisHamiltonHAM              Mercedes      1.07
# 30  2021           Austria    MaxVerstappenVER  Red Bull Racing RBPT      1.06
# 31  2021     Great Britain      SergioPerezPER  Red Bull Racing RBPT      1.28
# 32  2021           Hungary      PierreGaslyGAS            AlphaTauri      1.18
# 33  2021       Netherlands    LewisHamiltonHAM              Mercedes      1.11
# 34  2021             Italy  DanielRicciardoRIC               McLaren      1.24
# 35  2021            Russia      LandoNorrisNOR               McLaren      1.37
# 36  2021            Turkey   ValtteriBottasBOT              Mercedes      1.30
# 37  2021     United States    LewisHamiltonHAM              Mercedes      1.38
# 38  2021            Mexico   ValtteriBottasBOT              Mercedes      1.17
# 39  2021            Brazil      SergioPerezPER  Red Bull Racing RBPT      1.11
# 40  2021             Qatar    MaxVerstappenVER  Red Bull Racing RBPT      1.23
# 41  2021      Saudi Arabia    LewisHamiltonHAM              Mercedes      1.30
# 42  2021         Abu Dhabi    MaxVerstappenVER  Red Bull Racing RBPT      1.26
# 43  2020           Austria      LandoNorrisNOR               McLaren      1.07
# 44  2020            Styria      CarlosSainzSAI               McLaren      1.05
# 45  2020           Hungary    LewisHamiltonHAM              Mercedes      1.16
# 46  2020     Great Britain    MaxVerstappenVER  Red Bull Racing RBPT      1.27
# 47  2020  70th Anniversary    LewisHamiltonHAM              Mercedes      1.28
# 48  2020             Spain   ValtteriBottasBOT              Mercedes      1.18
# 49  2020           Belgium  DanielRicciardoRIC               Renault      1.47
# 50  2020             Italy    LewisHamiltonHAM              Mercedes      1.22
# 51  2020           Tuscany    LewisHamiltonHAM              Mercedes      1.18
# 52  2020            Russia   ValtteriBottasBOT              Mercedes      1.37
# 53  2020             Eifel    MaxVerstappenVER  Red Bull Racing RBPT      1.28
# 54  2020          Portugal    LewisHamiltonHAM              Mercedes      1.18
# 55  2020    Emilia Romagna    LewisHamiltonHAM              Mercedes      1.15
# 56  2020            Turkey      LandoNorrisNOR               McLaren      1.36
# 57  2020           Bahrain    MaxVerstappenVER  Red Bull Racing RBPT      1.32
# 58  2020            Sakhir    GeorgeRussellRUS              Mercedes      0.55
# 59  2020         Abu Dhabi  DanielRicciardoRIC               Renault      1.40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        60 non-null     int64
#  1   Grand Prix  60 non-null     object
#  2   Driver      60 non-null     object
#  3   Car         60 non-null     object
#  4   Lap Time    60 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
df.to_csv("F1-DHLFastestLap2020-22.csv", encoding = 'utf-8')
# Saves to Notebook; downloaded onto Mac
